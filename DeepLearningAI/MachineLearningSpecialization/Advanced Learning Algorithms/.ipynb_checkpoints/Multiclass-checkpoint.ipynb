# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.datasets import make_blobs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
def plotData(x, y):
    cmap = ['g', 'b', 'r', 'y']

    fig, ax = plt.subplots(1, 1)
    
    for i in range(len(cmap)):
        idx = y == i
        ax.scatter(x[idx, 0], x[idx, 1], c = cmap[i])

# %%
classes = 4
x, y = make_blobs(n_samples = 100, 
                  centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]], 
                  cluster_std = 1.0,
                  random_state = 30)
plotData(x, y)

# %% [markdown]
# ## Preferred
#
# 基於誤差等理由，在訓練的時候，會傾向將最後一層的sofmax改成線性激活函式，反過來在損時函式加上`from_logits = True`的參數。

# %% [markdown]
# ## SparseCategorialCrossentropy or CategoricalCrossEntropy
# - SparseCategorialCrossentropy: 當目標值直接儲存類別索引時使用. 例如有10個類別，那值的範圍就應該是0~9.
# - CategoricalCrossEntropy: 當目標值是以one-hot方式儲存類別時使用.

# %%
model = Sequential(
    [
        Input((2, )),
        Dense(2, activation = "relu"),
        Dense(4, activation = "linear"),
    ])

model.compile(loss = SparseCategoricalCrossentropy(from_logits = True),
             optimizer = Adam(0.01))

model.fit(x, y, epochs = 200)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5498
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 1.3959
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.3305
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2357
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.1731
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.0759
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.0550
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.0130
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.9481
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.9074
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.8466
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.7764
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7284
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.7213
# Epoch 15/200
# ...

# %%
def plotDecisionBoundary(x, y):
    cmap = ['g', 'b', 'r', 'y']

    fig, ax = plt.subplots(1, 1)

    x0Min = x[:, 0].min() - 0.5
    x0Max = x[:, 0].max() + 0.5
    x1Min = x[:, 1].min() - 0.5
    x1Max = x[:, 1].max() + 0.5
    
    xx0, xx1 = np.meshgrid(np.linspace(x0Min, x0Max, 100), 
                           np.linspace(x1Min, x1Max, 100))
    points = np.c_[xx0.ravel(), xx1.ravel()]
    pred = model.predict(points)
    pred = np.argmax(pred, axis = 1)
    pred = pred.reshape(xx0.shape)

    ax.contour(xx0, xx1, pred, linewidths = 1) 
    
    for i in range(len(cmap)):
        idx = y == i
        ax.scatter(x[idx, 0], x[idx, 1], c = cmap[i])

# %%
plotDecisionBoundary(x, y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step
